# %% [markdown]
# <a href="https://colab.research.google.com/github/Layanf76/Mining-project-/blob/main/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = 'diabetes_data 5.csv'
df = pd.read_csv(file_path)

print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])

print("\nDataset Sample:")
print(df.head())

print("\nColumn Names and Types:")
print(df.dtypes)
# Out:
# Number of Rows: 1879
# Number of Columns: 46
#
# Dataset Sample:
#    PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0       6000   44       0          1                    2               1
# 1       6001   51       1          0                    1               2
# 2       6002   89       1          0                    1               3
# 3       6003   21       1          1                    1               2
# 4       6004   27       1          0                    1               3
#
#          BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...  \
# 0  32.985284        1            4.499365          2.443385  ...
# 1  39.916764        0            1.578919          8.301264  ...
# 2  19.782251        0            1.177301          6.103395  ...
# 3  32.376881        1            1.714621          8.645465  ...
# 4  16.808600        0           15.462549          4.629383  ...
#
# ...
